# %% [markdown]
# # SignalDesk Health Check Notebook
#
# Interactive version of the analysis. Run cells top-to-bottom.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('product_usage_events.csv')
df.head()

# %%
from signaldesk_health_check import load_and_clean_data, compute_workflow_metrics

df = load_and_clean_data('product_usage_events.csv')
summary = compute_workflow_metrics(df, exclude_dq=True)
summary
